# %% [markdown]
# <a href="https://colab.research.google.com/github/navertp/Pembelajaran-Mesin-2026/blob/main/T1_244107020103_Evan_Raditya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PRAKTIKUM 1 - Konfigurasi Pada Google Colab

# %% [markdown]
# 1. Buka laman https://colab.research.google.com
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Login dengan akun Google Anda.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Pada halaman awal, pilih "+ New notebook" untuk membuat notebook baru.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Berikan judul notebook Anda pada bagian pojok kiri atas.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. Kemudian klik tombok "Connect" pada bagian kiri atas untuk menghubungkan notebook dengan perangkat komputasi (instances).
#
# ![image.png](data:image/png;base64,...)

# %%
# !pip install mne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 37.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: decorator
#     Found existing installation: decorator 4.4.2
#     Uninstalling decorator-4.4.2:
#       Successfully uninstalled decorator-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# moviepy 1.0.3 requires decorator<5.0,>=4.0.2, but you have decorator 5.3.1 which is incompatible.
# ...

# %% [markdown]
# # PRAKTIKUM 1 - Konfigurasi Pada Komputer Lokal

# %% [markdown]
# 1. Download dan instal Anaconda. Anaconda merupakan package instan untuk instalasi python berserta library library yang umum digunakan.
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Lakukan konfigurasi pada environment variabel pada saat proses instalasi Anaconda
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. Lakukan instalasi vscode (jika belum ada).

# %% [markdown]
# 4. Buat file baru bernama Praktikum1.ipynb pada vscode.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5.  Pada bagian pojok kanan atas, pastikan bertuliskan "base (Python 3.x.x)".
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # TUGAS PRAKTIKUM 1 - BAGIAN 1

# %% [markdown]
# 1.  Buat file notebook dengan nama T1_NIM_NAMA.ipynb .
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. Lakukan instalasi library berikut pada notebook,
# a. PyPREP
# b. Scipy
# c. wandb
# d. pyECG

# %%
# !pip install pyprep
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 1.8 MB/s eta 0:00:00
# ...

# %%
# !pip install scipy

# %%
# !pip install wandb

# %%
# !pip install pyecg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
#mengulang install library pyecg karena error
# !pip install ishneholterlib==2017.4.11
# !pip install wfdb==2.2.1 --no-deps
# !pip install scikit-learn
# !pip install pyecg --no-deps
# Out:
# ...
#   Using cached wfdb-2.2.1.tar.gz (94 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wfdb: filename=wfdb-2.2.1-py3-none-any.whl size=100359 sha256=f96f99a30f68d351429d2d300805e370879c90c6ff7db95316dd2eaf400954d1
#   Stored in directory: /root/.cache/pip/wheels/91/b2/e4/3e667e478d403736a546710d1cbcdd02fe670fabacaac6cc59
# Successfully built wfdb
# ...
#   Using cached pyECG-0.0.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# ...

# %% [markdown]
# 3. Jelaskan kegunakan masing-masing library tersebut.
#
# a. **Pyprep** : untuk melakukan tahap preprocessing awal pada data EEG (Elektroensefalografi) secara otomatis dan terstandardisasi
#
# b. **Scipy** : untuk melakukan komputasi ilmiah, matematika lanjutan, sains, dan teknik secara cepat dan efisien di dalam lingkungan
#
# c. **wandb** : untuk melacak, memvisualisasikan, dan mengelola eksperimen machine learning secara real-time
#
# d. **Pyecg** : untuk read dan write berbagai format berkas data elektrokardiogram (EKG/ECG) yang umum digunakan dalam penelitian medis

# %% [markdown]
# # TUGAS 1 - BAGIAN 2

# %% [markdown]
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan. Sertakan referensi yang digunakan.
# *   **Deepfake Tokoh Politik** : Beredar video deepfake yang menampilkan tokoh-tokoh politik dengan pernyataan palsu, yang disebarkan menjelang masa kampanye pemilu yang menyesatkan publik
#
# *   **Penyebaran hoaks** : Dengan kemampuan untuk mereplikasi pesan dalam jumlah besar dan menyebarkannya dalam waktu singkat, sistem ini sering digunakan untuk membentuk opini publik secara tidak jujur
#
# *    **Pengumpulan Data Tanpa Consent** : Sistem AI di aplikasi sering kali mengumpulkan data pribadi tanpa sepengetahuan pengguna, kemudian digunakan untuk kepentingan bisnis hingga disalahgunakan untuk manipulasi perilaku atau dijual kepada pihak ketiga
#
# **Referensi** : Oscar, K., & Hoesein, Z. A. (2025). Mendorong Regulasi Adaptif dan Progresif untuk Menghadapi Penyalahgunaan Artificial Intelligence di Indonesia. Journal of Innovative and Creativity (JoECY), 5(3), 31501–31511.

# %% [markdown]
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan.
#
# **Dampak**
# *  **Konsumsi Energi dan Emisi Karbon Ekstrem** : Operasional dan pelatihan model kecerdasan buatan modern membutuhkan pusat data dengan daya komputasi tingkat tinggi, yang secara langsung memicu lonjakan konsumsi daya listrik dan emisi gas rumah kaca secara signifikan.
#
# **Cara Mengatasi**
# *   **Penerapan Green IT dan Efisiensi Algoritma** : Mengintegrasikan mekanisme dan prinsip Green IT dalam rancang bangun sistem komputasi untuk meminimalisasi dampak energi. Hal ini dapat dicapai dengan teknik kompresi model (seperti pruning atau kuantisasi) agar algoritma lebih efisien dan membutuhkan daya komputasi yang jauh lebih kecil.
#
# **REFERENSI** : Hermanto, Edyson. (2025). Teknologi Artificial Intelligence dan Pelestarian Lingkungan dalam Perspektif Laudato Si'. Proceedings of the National Conference on Indonesian Philosophy and Theology, Volume 3 Nomor 2, 596-605.
